# %%
# %pylab notebook
import pandas as pd
import seaborn as sns
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.read_csv('../output/High-rise_20160529_204744/Planning_Weighted/trips.log', sep=' ', index_col='clientID')
df.head()
# Out:
#           partySize  elevatorID  arrivalFloor  dropoffFloor  createTime  \
# clientID
# 11745             1           0             4            15         124
# 11753             1           0            12            36         131
# 11765             1           0            24            28         161
# 11773             1           0            32            25         162
# 11769             1           0            28            19         143
#
#           pickupTime  dropoffTime
# clientID
# 11745            128          139
# 11753            136          160
# 11765            172          176
# 11773            164          179
# 11769            168          185

# %%
df['arrivalFloor'].value_counts()
# Out:
# 0     30
# 4     30
# 12    30
# 13    30
# 8     30
# 16    30
# 17    30
# 20    30
# 21    30
# 5     30
# 25    30
# 24    30
# 28    30
# 29    30
# 1     30
# 32    30
# 33    30
# 36    30
# 9     30
# 26    22
# 23    22
# 18    22
# 34    22
# 14    22
# 35    22
# 10    21
# 2     21
# 6     21
# 38    21
# 11    21
# 37    21
# 22    21
# 30    21
# 15    16
# 7     16
# 27    16
# 3     16
# 31    16
# 19    16
# Name: arrivalFloor, dtype: int64

# %%
sns.barplot(x=df.arrivalFloor.value_counts().index,
            y=df.arrivalFloor.value_counts())
# Out:
# <img src="data:image/png;base64,...">
