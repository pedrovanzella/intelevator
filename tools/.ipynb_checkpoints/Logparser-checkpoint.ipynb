# %%
# %pylab notebook
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Read the file

# %%
df = pd.read_csv('../output/teste_20160529_152643/Simple with better_nearest_neighbour/trips.log', sep=' ', index_col='clientID')
df.head()
# Out:
#           partySize  elevatorID  arrivalFloor  dropoffFloor  createTime  pickupTime  dropoffTime
# clientID
# 466               1           0             0             1         145         146          147
# 473               1           1             0             2         280         281          283
# 467               1           0             1             0         295         296          297
# 474               1           0             0             6         429         430          436
# 470               1           0             4             2         452         454          456

# %% [markdown]
# # Total number of clients per elevator

# %%
df['elevatorID'].value_counts()
# Out:
# 0    52
# 1    33
# 2    31
# 4    18
# 3    16
# Name: elevatorID, dtype: int64

# %%
df['elevatorID'].value_counts().plot(kind='bar') # 7
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# # Arrivals per floor (client creation)

# %%
df['arrivalFloor'].value_counts().plot(kind='bar') # 2

# %% [markdown]
# # Dropoffs per floor (client death)

# %%
df['dropoffFloor'].value_counts().plot(kind='bar') # 3

# %% [markdown]
# # Average wait time per floor

# %%
df['waitTime'] = df['pickupTime'] - df['createTime']
df.groupby('arrivalFloor').aggregate(np.average)
# Out:
#               partySize  elevatorID  dropoffFloor   createTime   pickupTime  dropoffTime  waitTime
# arrivalFloor
# 0                     1    1.800000      3.300000  2349.233333  2351.566667  2354.866667  2.333333
# 1                     1    1.366667      3.033333  4717.066667  4718.733333  4721.233333  1.666667
# 2                     1    1.136364      3.545455  5146.227273  5147.727273  5149.909091  1.500000
# 3                     1    1.625000      2.000000  5085.062500  5086.312500  5088.437500  1.250000
# 4                     1    1.000000      2.700000  5195.650000  5196.800000  5199.200000  1.150000
# 5                     1    1.636364      3.136364  5195.545455  5196.681818  5208.681818  1.136364
# 6                     1    1.300000      2.700000  4987.900000  4988.900000  4992.200000  1.000000
