# %%
# %pylab notebook
import pandas as pd
import seaborn as sns
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Read the file

# %%
df = pd.read_csv('../output/teste_20160529_152643/Simple with better_nearest_neighbour/trips.log', sep=' ', index_col='clientID')
df.head()
# Out:
#           partySize  elevatorID  arrivalFloor  dropoffFloor  createTime  \
# clientID
# 466               1           0             0             1         145
# 473               1           1             0             2         280
# 467               1           0             1             0         295
# 474               1           0             0             6         429
# 470               1           0             4             2         452
#
#           pickupTime  dropoffTime
# clientID
# 466              146          147
# 473              281          283
# 467              296          297
# 474              430          436
# 470              454          456

# %% [markdown]
# # Total number of clients per elevator

# %%
df['elevatorID'].value_counts().head()
# Out:
# 0    52
# 1    33
# 2    31
# 4    18
# 3    16
# Name: elevatorID, dtype: int64

# %%
ax = sns.barplot(x=df.elevatorID.value_counts().index,
                 y=df.elevatorID.value_counts())
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# # Arrivals per floor (client creation)

# %%
df['arrivalFloor'].value_counts()
# Out:
# 1    30
# 0    30
# 5    22
# 2    22
# 4    20
# 3    16
# 6    10
# Name: arrivalFloor, dtype: int64

# %%
sns.barplot(x=df.arrivalFloor.value_counts().index,
            y=df.arrivalFloor.value_counts())
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# # Dropoffs per floor (client death)

# %%
df['dropoffFloor'].value_counts()
# Out:
# 5    27
# 0    26
# 4    25
# 2    22
# 3    18
# 6    17
# 1    15
# Name: dropoffFloor, dtype: int64

# %%
sns.barplot(x=df.dropoffFloor.value_counts().index,
            y=df.dropoffFloor.value_counts())
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# # Average wait time per floor

# %%
df['waitTime'] = df['pickupTime'] - df['createTime']
waits = df.groupby('arrivalFloor', as_index=False).aggregate(np.average)['waitTime']
waits.head()
# Out:
# 0    2.333333
# 1    1.666667
# 2    1.500000
# 3    1.250000
# 4    1.150000
# Name: waitTime, dtype: float64

# %%
sns.barplot(x=waits.index,
            y=waits)
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# # Average travel time

# %%
df['travelTime'] = df['dropoffTime'] - df['pickupTime']
traveltimes = df.groupby('arrivalFloor', as_index=False).aggregate(np.average)['travelTime']
traveltimes.head()
# Out:
# 0    3.300000
# 1    2.500000
# 2    2.181818
# 3    2.125000
# 4    2.400000
# Name: travelTime, dtype: float64

# %%
sns.barplot(x=traveltimes.index, y=traveltimes)
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# # Passenger flow matrix

# %%
df.head()
# Out:
#           partySize  elevatorID  arrivalFloor  dropoffFloor  createTime  pickupTime  dropoffTime  waitTime  travelTime
# clientID
# 466               1           0             0             1         145         146          147         1           1
# 473               1           1             0             2         280         281          283         1           2
# 467               1           0             1             0         295         296          297         1           1
# 474               1           0             0             6         429         430          436         1           6
# 470               1           0             4             2         452         454          456         2           2
