# %%
# %pylab notebook
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Low Rise

# %%
N = 5
waits = (5.4046, 3.5144, 3.3547, 3.7149, 3.1731)
journeys = (4.4949, 4.4700, 4.4674, 4.4719, 4.4770)

# %%
ind = np.arange(N)  # the x locations for the groups
width = 0.35       # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(ind, waits, width, color='darkblue')
rects2 = ax.bar(ind + width, journeys, width, color='blue')

# add some text for labels, title and axes ticks
ax.set_ylabel('Tempo')
ax.set_title('Tempo Médio de Espera e de Viagem por Scheduler (Low-rise)')
ax.set_xticks(ind + width)
ax.set_xticklabels(('Random', 'NN', 'BNN', 'Weighted', 'Planning'))

ax.legend((rects1[0], rects2[0]), ('Espera', 'Viagem'))
savefig('low-rise-times.eps', bbox_inches='tight')
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# # High Rise

# %%
N = 5
waits = (25.9981, 20.3395, 13.5243, 31.0373, 8.6901)
journeys = (15.2595, 15.0993, 15.0550, 14.9915, 15.1627)

ind = np.arange(N)  # the x locations for the groups
width = 0.35       # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(ind, waits, width, color='darkblue')
rects2 = ax.bar(ind + width, journeys, width, color='blue')

# add some text for labels, title and axes ticks
ax.set_ylabel('Tempo')
ax.set_title('Tempo Médio de Espera e de Viagem por Scheduler (High-rise)')
ax.set_xticks(ind + width)
ax.set_xticklabels(('Random', 'NN', 'BNN', 'Weighted', 'Planning'))

ax.legend((rects1[0], rects2[0]), ('Espera', 'Viagem'))
savefig('high-rise-times.eps', bbox_inches='tight')
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# # Skyscraper

# %%
N = 5
waits = (442.2165, 343.5988, 287.1803, 293.8791, 78.3855)
journeys = (54.7816, 54.9789, 55.0124, 54.6163, 60.1728)

ind = np.arange(N)  # the x locations for the groups
width = 0.35       # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(ind, waits, width, color='darkblue')
rects2 = ax.bar(ind + width, journeys, width, color='blue')

# add some text for labels, title and axes ticks
ax.set_ylabel('Tempo')
ax.set_title('Tempo Médio de Espera e de Viagem por Scheduler (Skyscraper)')
ax.set_xticks(ind + width)
ax.set_xticklabels(('Random', 'NN', 'BNN', 'Weighted', 'Planning'))

ax.legend((rects1[0], rects2[0]), ('Espera', 'Viagem'))
savefig('high-rise-times.eps', bbox_inches='tight')
